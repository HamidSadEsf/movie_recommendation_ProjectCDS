# %% [markdown]
# # Colloborative filtering workflow

# %%
# preprocess and save data for collaborative filtering modelling
from data_script.preprocess_collaborative import hamid_user_id, sveta_user_id
# Out:
# Creating dataframes...
# Filtering movies and users...
# Out of total of  10370  movies,  8338  are considered rare and will be removed.
# The final number of movies is  2032
# Out of total of  138493  users,  138046  are considered lazy and will be removed.
# The final number of users is  447
# Adding Sviatlana's and Hamid's ratings...
# Sveta 's user id is 110597
# Hamid 's user id is 102850
# Creating the pivot matrix...
# The resulting sparcity of the matrix is: 0.4620430410293578
# Preparing the final rating matrix...
# Data preprocesssing for collaborative filtering modeling is completed!

# %%
from model.CollaborativeFilteringRec import cf_model

# %%
import numpy as np
import pandas as pd
from collections import defaultdict

from surprise import Dataset
from surprise import Reader
from surprise import BaselineOnly, Dataset, Reader, SVD, KNNBasic, KNNBaseline, KNNWithMeans

from surprise.model_selection import GridSearchCV
from surprise.model_selection import train_test_split

#Get the final ratings matrix
print("Getting the ratings matrix...")
ratings = pd.read_csv('./data/processed/final_ratings.csv')
movie_df = pd.read_csv('./data/external/movies.csv')

#Prepare data in the Surprise's format
print("Preparing data in the Suprise format...")
reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(ratings[["userId", "movieId", "rating"]], reader)
# Out:
# Getting the ratings matrix...
# Preparing data in the Suprise format...

# %%
#Prepare train and test data (what about validation?)
trainset, testset = train_test_split(data, test_size=.25, random_state=42)

# %%
#KNN-based memory based model
sim_options = {'name': 'msd',
               'min_support': 5,
               'user_based': False}

knn_basic = KNNBasic(k=30,sim_options=sim_options)

# %%
knn_basic_model = cf_model(knn_basic, trainset, testset, data)
knn_basic_model.fit_and_predict()
knn_basic_model.cross_validate()
knn_basic_model.recommend(sveta_user_id, 20).merge(movie_df, on='movieId', how='left')
# Out:
# Fitting the train data...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Predicting the test data...
# RMSE: 0.7648
# RMSE for the predicted result is 0.765
# Cross Validating the data...
# Mean CV RMSE is 0.759
# Recommending top 20 products for userid : 110597 ...
#     userId movieId    rating  \
# 0   110597    1206  4.467957
# 1   110597     541  4.405479
# 2   110597     527  4.288721
# 3   110597   58559  4.279162
# 4   110597    4973  4.204840
# 5   110597    4993  4.196493
# 6   110597    5952  4.117202
# 7   110597   48385  4.011684
# 8   110597    1036  3.985201
# 9   110597    4011  3.980190
# 10  110597    3147  3.863787
# 11  110597    4720  3.834209
# 12  110597    6365  3.774693
# 13  110597   53125  3.743627
# 14  110597    8961  3.732125
# 15  110597    6539  3.641822
# 16  110597   95058  3.312378
# 17  110597    3569  3.312378
# 18  110597  108727  3.312378
# 19  110597  108981  3.312378
#
#                                                 title  \
# 0                          Clockwork Orange, A (1971)
# 1                                 Blade Runner (1982)
# 2                             Schindler's List (1993)
# 3                             Dark Knight, The (2008)
# 4   Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 5   Lord of the Rings: The Fellowship of the Ring,...
# 6       Lord of the Rings: The Two Towers, The (2002)
# 7   Borat: Cultural Learnings of America for Make ...
# 8                                     Die Hard (1988)
# 9                                       Snatch (2000)
# 10                             Green Mile, The (1999)
# 11                                 Others, The (2001)
# 12                        Matrix Reloaded, The (2003)
# 13    Pirates of the Caribbean: At World's End (2007)
# 14                            Incredibles, The (2004)
# 15  Pirates of the Caribbean: The Curse of the Bla...
# 16                                 Cosmopolis  (2012)
# 17                     Idiots, The (Idioterne) (1998)
# 18                      Nymphomaniac: Volume I (2013)
# 19                     Nymphomaniac: Volume II (2013)
#
#                                         genres
# 0                  Crime|Drama|Sci-Fi|Thriller
# 1                       Action|Sci-Fi|Thriller
# 2                                    Drama|War
# 3                      Action|Crime|Drama|IMAX
# 4                               Comedy|Romance
# 5                            Adventure|Fantasy
# 6                            Adventure|Fantasy
# 7                                       Comedy
# 8                        Action|Crime|Thriller
# 9                        Comedy|Crime|Thriller
# 10                                 Crime|Drama
# 11               Drama|Horror|Mystery|Thriller
# 12       Action|Adventure|Sci-Fi|Thriller|IMAX
# 13             Action|Adventure|Comedy|Fantasy
# 14  Action|Adventure|Animation|Children|Comedy
# 15             Action|Adventure|Comedy|Fantasy
# 16                                       Drama
# 17                                Comedy|Drama
# 18                                       Drama
# 19                               Drama|Mystery

# %%
knn_basic_model.recommend(hamid_user_id, 20).merge(movie_df, on='movieId', how='left')
# Out:
# Recommending top 20 products for userid : 102850 ...
#     userId movieId    rating  \
# 0   102850     924  4.222926
# 1   102850     923  4.164150
# 2   102850    2010  4.151352
# 3   102850    2019  4.111878
# 4   102850     593  4.095610
# 5   102850    1228  4.084757
# 6   102850    1217  4.052776
# 7   102850    1206  4.052221
# 8   102850    3462  4.027317
# 9   102850    1211  4.016986
# 10  102850    3160  4.014812
# 11  102850      50  3.993237
# 12  102850    1222  3.992477
# 13  102850    1251  3.963904
# 14  102850    1248  3.955417
# 15  102850    2726  3.935694
# 16  102850     741  3.922423
# 17  102850   27773  3.898057
# 18  102850     307  3.841689
# 19  102850   31658  3.812772
#
#                                                 title  \
# 0                        2001: A Space Odyssey (1968)
# 1                                 Citizen Kane (1941)
# 2                                   Metropolis (1927)
# 3         Seven Samurai (Shichinin no samurai) (1954)
# 4                    Silence of the Lambs, The (1991)
# 5                                  Raging Bull (1980)
# 6                                          Ran (1985)
# 7                          Clockwork Orange, A (1971)
# 8                                 Modern Times (1936)
# 9    Wings of Desire (Himmel über Berlin, Der) (1987)
# 10                                    Magnolia (1999)
# 11                         Usual Suspects, The (1995)
# 12                           Full Metal Jacket (1987)
# 13                                  8 1/2 (8½) (1963)
# 14                               Touch of Evil (1958)
# 15                                Killing, The (1956)
# 16         Ghost in the Shell (Kôkaku kidôtai) (1995)
# 17                                     Old Boy (2003)
# 18   Three Colors: Blue (Trois couleurs: Bleu) (1993)
# 19  Howl's Moving Castle (Hauru no ugoku shiro) (2...
#
#                                  genres
# 0                Adventure|Drama|Sci-Fi
# 1                         Drama|Mystery
# 2                          Drama|Sci-Fi
# 3                Action|Adventure|Drama
# 4                 Crime|Horror|Thriller
# 5                                 Drama
# 6                             Drama|War
# 7           Crime|Drama|Sci-Fi|Thriller
# 8                  Comedy|Drama|Romance
# 9                 Drama|Fantasy|Romance
# 10                                Drama
# 11               Crime|Mystery|Thriller
# 12                            Drama|War
# 13                        Drama|Fantasy
# 14             Crime|Film-Noir|Thriller
# 15                      Crime|Film-Noir
# 16                     Animation|Sci-Fi
# 17                     Mystery|Thriller
# 18                                Drama
# 19  Adventure|Animation|Fantasy|Romance

# %%
sim_options = {'name': 'cosine',
               'min_support': 5,
               'user_based': False}

knn_with_means = KNNWithMeans(k=25,sim_options=sim_options)

# %%
knn_with_means_model = cf_model(knn_with_means, trainset, testset, data)
knn_with_means_model.fit_and_predict()
knn_with_means_model.cross_validate()
knn_with_means_model.recommend(sveta_user_id, 20).merge(movie_df, on='movieId', how='left')
# Out:
# Fitting the train data...
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Predicting the test data...
# RMSE: 0.7731
# RMSE for the predicted result is 0.773
# Cross Validating the data...
# Mean CV RMSE is 0.768
# Recommending top 20 products for userid : 110597 ...
#     userId movieId    rating  \
# 0   110597  202439  5.000000
# 1   110597    1206  4.569605
# 2   110597   58559  4.385288
# 3   110597     527  4.348882
# 4   110597     541  4.340022
# 5   110597    4993  4.241033
# 6   110597    4973  4.198562
# 7   110597    5952  4.136885
# 8   110597    1036  4.032884
# 9   110597    4011  3.909083
# 10  110597    8961  3.906057
# 11  110597   48385  3.860283
# 12  110597    3147  3.742360
# 13  110597    6539  3.670402
# 14  110597    4720  3.642564
# 15  110597   95058  3.312378
# 16  110597    3569  3.312378
# 17  110597  108727  3.312378
# 18  110597  108981  3.312378
# 19  110597  105844  3.312378
#
#                                                 title  \
# 0                                                 NaN
# 1                          Clockwork Orange, A (1971)
# 2                             Dark Knight, The (2008)
# 3                             Schindler's List (1993)
# 4                                 Blade Runner (1982)
# 5   Lord of the Rings: The Fellowship of the Ring,...
# 6   Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 7       Lord of the Rings: The Two Towers, The (2002)
# 8                                     Die Hard (1988)
# 9                                       Snatch (2000)
# 10                            Incredibles, The (2004)
# 11  Borat: Cultural Learnings of America for Make ...
# 12                             Green Mile, The (1999)
# 13  Pirates of the Caribbean: The Curse of the Bla...
# 14                                 Others, The (2001)
# 15                                 Cosmopolis  (2012)
# 16                     Idiots, The (Idioterne) (1998)
# 17                      Nymphomaniac: Volume I (2013)
# 18                     Nymphomaniac: Volume II (2013)
# 19                            12 Years a Slave (2013)
#
#                                         genres
# 0                                          NaN
# 1                  Crime|Drama|Sci-Fi|Thriller
# 2                      Action|Crime|Drama|IMAX
# 3                                    Drama|War
# 4                       Action|Sci-Fi|Thriller
# 5                            Adventure|Fantasy
# 6                               Comedy|Romance
# 7                            Adventure|Fantasy
# 8                        Action|Crime|Thriller
# 9                        Comedy|Crime|Thriller
# 10  Action|Adventure|Animation|Children|Comedy
# 11                                      Comedy
# 12                                 Crime|Drama
# 13             Action|Adventure|Comedy|Fantasy
# 14               Drama|Horror|Mystery|Thriller
# 15                                       Drama
# 16                                Comedy|Drama
# 17                                       Drama
# 18                               Drama|Mystery
# 19                                       Drama

# %%
svd = SVD()
svd_model = cf_model(svd, trainset, testset, data)
svd_model.fit_and_predict()
svd_model.cross_validate()
svd_model.recommend(sveta_user_id, 20).merge(movie_df, on='movieId', how='left')
# Out:
# Fitting the train data...
# Predicting the test data...
# RMSE: 0.7417
# RMSE for the predicted result is 0.742
# Cross Validating the data...
# Mean CV RMSE is 0.737
# Recommending top 20 products for userid : 110597 ...
#     userId movieId    rating  \
# 0   110597   58559  4.849629
# 1   110597     527  4.836052
# 2   110597    1206  4.563817
# 3   110597    1036  4.445824
# 4   110597     541  4.382573
# 5   110597    3147  4.286140
# 6   110597    4973  4.239556
# 7   110597   48385  4.201484
# 8   110597    4011  4.142976
# 9   110597    4720  4.118383
# 10  110597    5952  4.020248
# 11  110597    8961  3.962235
# 12  110597    4993  3.936133
# 13  110597    6539  3.855024
# 14  110597   95058  3.795900
# 15  110597    3569  3.795900
# 16  110597  108727  3.795900
# 17  110597  108981  3.795900
# 18  110597  105844  3.795900
# 19  110597  182723  3.795900
#
#                                                 title  \
# 0                             Dark Knight, The (2008)
# 1                             Schindler's List (1993)
# 2                          Clockwork Orange, A (1971)
# 3                                     Die Hard (1988)
# 4                                 Blade Runner (1982)
# 5                              Green Mile, The (1999)
# 6   Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 7   Borat: Cultural Learnings of America for Make ...
# 8                                       Snatch (2000)
# 9                                  Others, The (2001)
# 10      Lord of the Rings: The Two Towers, The (2002)
# 11                            Incredibles, The (2004)
# 12  Lord of the Rings: The Fellowship of the Ring,...
# 13  Pirates of the Caribbean: The Curse of the Bla...
# 14                                 Cosmopolis  (2012)
# 15                     Idiots, The (Idioterne) (1998)
# 16                      Nymphomaniac: Volume I (2013)
# 17                     Nymphomaniac: Volume II (2013)
# 18                            12 Years a Slave (2013)
# 19                                                NaN
#
#                                         genres
# 0                      Action|Crime|Drama|IMAX
# 1                                    Drama|War
# 2                  Crime|Drama|Sci-Fi|Thriller
# 3                        Action|Crime|Thriller
# 4                       Action|Sci-Fi|Thriller
# 5                                  Crime|Drama
# 6                               Comedy|Romance
# 7                                       Comedy
# 8                        Comedy|Crime|Thriller
# 9                Drama|Horror|Mystery|Thriller
# 10                           Adventure|Fantasy
# 11  Action|Adventure|Animation|Children|Comedy
# 12                           Adventure|Fantasy
# 13             Action|Adventure|Comedy|Fantasy
# 14                                       Drama
# 15                                Comedy|Drama
# 16                                       Drama
# 17                               Drama|Mystery
# 18                                       Drama
# 19                                         NaN
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
