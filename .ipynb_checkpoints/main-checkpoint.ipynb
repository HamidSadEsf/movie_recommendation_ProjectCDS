# %%
# Import all necessary modules
import pandas as pd
import numpy as np
import CollaborativeFilteringRec as cfr
from scipy.sparse import csr_matrix, load_npz

# %%
# load utility matrix 
util_mat = pd.read_csv('matrices/pivot.csv', index_col='userId')

# %%
# Choose randomly a userId
user_id = np.random.choice(util_mat.index)
print("Let's make predictions of ratings for the user", user_id, "!")

cfr_ratings_pred = cfr.get_predictions(user_id, util_mat, 20)
print("Here they are:")
cfr_ratings_pred.head(20)
# Out:
# Let's make predictions of ratings for the user 135015 !
# Here they are:
# /home/mumu/Documents/DS/movie_recommendation_ProjectCDS/CollaborativeFilteringRec.py:32: RuntimeWarning: Mean of empty slice
#   av_ratings = np.nanmean(mat_array, axis=0)
#    movieId    rating
# 0        1  3.852349
# 1        2  3.121528
# 2        3  2.942529
# 3        4  1.961538
# 4        5  2.639241
# 5        6  3.848485
# 6        7  2.782258
# 7        8  2.750000
# 8        9  2.571429
# 9       10  3.613793
# 10      11  3.338235
# 11      12  2.466102
# 12      13  2.714286
# 13      14  3.108696
# 14      15  2.601852
# 15      16  3.900826
# 16      17  3.171429
# 17      18  3.300000
# 18      19  3.025547
# 19      20  2.794118
