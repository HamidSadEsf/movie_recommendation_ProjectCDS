# %% [markdown]
# # Colloborative filtering workflow

# %%
import numpy as np
import pandas as pd
import random
from collections import defaultdict

from surprise import Dataset
from surprise import Reader
from surprise import BaselineOnly, Dataset, Reader, SVD, KNNBasic, KNNBaseline, KNNWithMeans, dump

from surprise.model_selection import GridSearchCV
from surprise.model_selection import train_test_split

from model.CollaborativeFilteringRec import cf_model

from evaluation.Evaluate import Evaluate

# %% [markdown]
# ## Data preprocessing

# %%
# preprocess and save data for collaborative filtering modelling
from data_script.preprocess_collaborative import hamid_user_id, sveta_user_id, anti_hamid_user_id, anti_sveta_user_id
# Out:
# Creating dataframes...
# Filtering users...
# Out of total of  138493  users,  64051  are considered lazy and will be removed.
# The final number of users is  74442
# Randomly choosing 400 users...
# Adding Sviatlana's and Hamid's ratings... we are lazy users, but still...
# Sveta 's user id is 47347
# Hamid 's user id is 23579
# Adding anti-Sviatlana's and anti-Hamid's ratings... they are lazy users, but still...
# anti-Sveta 's user id is 14433
# anti-Hamid 's user id is 96258
# Now, the final number of users is  404
# Filtering movies...
# Out of total of  7899  movies,  5855  are considered rare and will be removed.
# The final number of movies is  2044
# Creating the pivot matrix...
# The resulting sparcity of the matrix is: 0.9085211970316406
# Preparing the final rating matrix...
# Data preprocesssing for collaborative filtering modeling is completed!

# %%
hamid_user_id, sveta_user_id, anti_hamid_user_id, anti_sveta_user_id = (hamid_user_id, sveta_user_id, anti_hamid_user_id, anti_sveta_user_id)

# %%
#Get the final ratings matrix
print("Getting the ratings matrix...")
ratings = pd.read_csv('./data/processed/final_ratings.csv')
movie_df = pd.read_csv('./data/external/movies.csv')
# Out:
# Getting the ratings matrix...

# %%
#Prepare data in the Surprise's format
print("Preparing data in the Suprise format...")
reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(ratings[["userId", "movieId", "rating"]], reader)

#Prepare train and test data (what about validation?)
#trainset, testset = train_test_split(data, test_size=.25, random_state=42)

# For final preditions
trainset = data.build_full_trainset()
testset = trainset.build_anti_testset()
# Out:
# Preparing data in the Suprise format...

# %% [markdown]
# ## Pre-clustering users

# %% [markdown]
# ## KNN Basic

# %%
#KNN-based memory based model
sim_options = {'name': 'msd',
               'min_support': 3,
               'user_based': True}

knn_basic = KNNBasic(k=25,sim_options=sim_options)

# %%
knn_basic_model = cf_model(knn_basic, trainset, testset, data, 20)
knn_basic_model.fit_and_predict()
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.5227
# 0.523

# %%
knn_basic_model.cross_validate()
# Out:
# Cross Validating the data...
# Mean CV RMSE is 0.886
# 0.886

# %%
dump.dump('model/trained_models/KNNBasic_Model',algo=knn_basic_model,predictions=knn_basic_model.pred_test)

# %%
knn_basic_model.recommend_all(sveta_user_id).merge(movie_df, on='movieId', how='left').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   47347    3030     4.643503
# 1   47347    1260     4.605416
# 2   47347    2028     4.560241
# 3   47347    3089     4.558230
# 4   47347     912     4.548456
# 5   47347     745     4.535521
# 6   47347     110     4.529197
# 7   47347     750     4.526569
# 8   47347    1252     4.516153
# 9   47347    1225     4.507412
# 10  47347    1203     4.507336
# 11  47347    2858     4.502556
# 12  47347    3307     4.489839
# 13  47347    1218     4.471579
# 14  47347     260     4.468708
# 15  47347    1219     4.462806
# 16  47347    3629     4.458971
# 17  47347     908     4.447429
# 18  47347    1952     4.438567
# 19  47347     942     4.436087
#
#                                                 title  \
# 0                                      Yojimbo (1961)
# 1                                            M (1931)
# 2                          Saving Private Ryan (1998)
# 3   Bicycle Thieves (a.k.a. The Bicycle Thief) (a....
# 4                                   Casablanca (1942)
# 5              Wallace & Gromit: A Close Shave (1995)
# 6                                   Braveheart (1995)
# 7   Dr. Strangelove or: How I Learned to Stop Worr...
# 8                                    Chinatown (1974)
# 9                                      Amadeus (1984)
# 10                                12 Angry Men (1957)
# 11                             American Beauty (1999)
# 12                                 City Lights (1931)
# 13          Killer, The (Die xue shuang xiong) (1989)
# 14          Star Wars: Episode IV - A New Hope (1977)
# 15                                      Psycho (1960)
# 16                              Gold Rush, The (1925)
# 17                          North by Northwest (1959)
# 18                             Midnight Cowboy (1969)
# 19                                       Laura (1944)
#
#                                        genres
# 0                            Action|Adventure
# 1                    Crime|Film-Noir|Thriller
# 2                            Action|Drama|War
# 3                                       Drama
# 4                               Drama|Romance
# 5                   Animation|Children|Comedy
# 6                            Action|Drama|War
# 7                                  Comedy|War
# 8            Crime|Film-Noir|Mystery|Thriller
# 9                                       Drama
# 10                                      Drama
# 11                               Comedy|Drama
# 12                       Comedy|Drama|Romance
# 13                Action|Crime|Drama|Thriller
# 14                    Action|Adventure|Sci-Fi
# 15                               Crime|Horror
# 16                   Adventure|Comedy|Romance
# 17  Action|Adventure|Mystery|Romance|Thriller
# 18                                      Drama
# 19                    Crime|Film-Noir|Mystery

# %%
knn_basic_model.recommend_all(anti_sveta_user_id).merge(movie_df, on='movieId', how='left').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   14433    3030     4.651951
# 1   14433    1260     4.622471
# 2   14433    3089     4.582985
# 3   14433    3307     4.537921
# 4   14433     904     4.480727
# 5   14433    3629     4.461928
# 6   14433     908     4.459043
# 7   14433     922     4.446178
# 8   14433    1212     4.441824
# 9   14433    1218     4.427738
# 10  14433    1254     4.424066
# 11  14433    7156     4.423974
# 12  14433     930     4.417293
# 13  14433     260     4.396290
# 14  14433    2732     4.390231
# 15  14433     950     4.389569
# 16  14433    2731     4.384400
# 17  14433    1251     4.376323
# 18  14433     942     4.367635
# 19  14433    1952     4.359504
#
#                                                 title  \
# 0                                      Yojimbo (1961)
# 1                                            M (1931)
# 2   Bicycle Thieves (a.k.a. The Bicycle Thief) (a....
# 3                                  City Lights (1931)
# 4                                  Rear Window (1954)
# 5                               Gold Rush, The (1925)
# 6                           North by Northwest (1959)
# 7       Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 8                               Third Man, The (1949)
# 9           Killer, The (Die xue shuang xiong) (1989)
# 10           Treasure of the Sierra Madre, The (1948)
# 11  Fog of War: Eleven Lessons from the Life of Ro...
# 12                                   Notorious (1946)
# 13          Star Wars: Episode IV - A New Hope (1977)
# 14                Jules and Jim (Jules et Jim) (1961)
# 15                               Thin Man, The (1934)
# 16     400 Blows, The (Les quatre cents coups) (1959)
# 17                                  8 1/2 (8½) (1963)
# 18                                       Laura (1944)
# 19                             Midnight Cowboy (1969)
#
#                                        genres
# 0                            Action|Adventure
# 1                    Crime|Film-Noir|Thriller
# 2                                       Drama
# 3                        Comedy|Drama|Romance
# 4                            Mystery|Thriller
# 5                    Adventure|Comedy|Romance
# 6   Action|Adventure|Mystery|Romance|Thriller
# 7                     Drama|Film-Noir|Romance
# 8                  Film-Noir|Mystery|Thriller
# 9                 Action|Crime|Drama|Thriller
# 10             Action|Adventure|Drama|Western
# 11                            Documentary|War
# 12                 Film-Noir|Romance|Thriller
# 13                    Action|Adventure|Sci-Fi
# 14                              Drama|Romance
# 15                               Comedy|Crime
# 16                                Crime|Drama
# 17                              Drama|Fantasy
# 18                    Crime|Film-Noir|Mystery
# 19                                      Drama

# %% [markdown]
# ## KNN Pearson

# %%
#KNN-based memory based model
sim_options = {'name': 'pearson',
               'min_support': 3,
               'user_based': True}

knn_pearson = KNNBasic(k=25,sim_options=sim_options)

# %%
knn_pearson_model = cf_model(knn_pearson, trainset, testset, data, 20)
knn_pearson_model.fit_and_predict()
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.5808
# 0.581

# %%
knn_pearson_model.cross_validate()
# Out:
# Cross Validating the data...
# Mean CV RMSE is 0.912
# 0.912

# %%
dump.dump('model/trained_models/KNNPearson_Model',algo=knn_pearson_model,predictions=knn_pearson_model.pred_test)

# %%
knn_pearson_model.recommend_all(sveta_user_id).merge(movie_df, on='movieId', how='left').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   47347     125     4.821921
# 1   47347    1264     4.721006
# 2   47347     932     4.659013
# 3   47347    2303     4.610191
# 4   47347   81834     4.584908
# 5   47347    1148     4.582854
# 6   47347    1280     4.548846
# 7   47347     262     4.540247
# 8   47347    1234     4.526385
# 9   47347    3030     4.519924
# 10  47347    1218     4.519276
# 11  47347   72226     4.516674
# 12  47347    3629     4.511956
# 13  47347    4642     4.510122
# 14  47347    1147     4.490430
# 15  47347    1131     4.481942
# 16  47347     745     4.481906
# 17  47347    1203     4.459126
# 18  47347     123     4.450359
# 19  47347    3035     4.448390
#
#                                                 title  \
# 0                       Flirting With Disaster (1996)
# 1                                         Diva (1981)
# 2                       Affair to Remember, An (1957)
# 3                                    Nashville (1975)
# 4   Harry Potter and the Deathly Hallows: Part 1 (...
# 5         Wallace & Gromit: The Wrong Trousers (1993)
# 6   Raise the Red Lantern (Da hong deng long gao g...
# 7                           Little Princess, A (1995)
# 8                                   Sting, The (1973)
# 9                                      Yojimbo (1961)
# 10          Killer, The (Die xue shuang xiong) (1989)
# 11                           Fantastic Mr. Fox (2009)
# 12                              Gold Rush, The (1925)
# 13                   Hedwig and the Angry Inch (2000)
# 14                          When We Were Kings (1996)
# 15                            Jean de Florette (1986)
# 16             Wallace & Gromit: A Close Shave (1995)
# 17                                12 Angry Men (1957)
# 18      Chungking Express (Chung Hing sam lam) (1994)
# 19                              Mister Roberts (1955)
#
#                                        genres
# 0                                      Comedy
# 1       Action|Drama|Mystery|Romance|Thriller
# 2                               Drama|Romance
# 3                               Drama|Musical
# 4               Action|Adventure|Fantasy|IMAX
# 5             Animation|Children|Comedy|Crime
# 6                                       Drama
# 7                              Children|Drama
# 8                                Comedy|Crime
# 9                            Action|Adventure
# 10                Action|Crime|Drama|Thriller
# 11  Adventure|Animation|Children|Comedy|Crime
# 12                   Adventure|Comedy|Romance
# 13                       Comedy|Drama|Musical
# 14                                Documentary
# 15                              Drama|Mystery
# 16                  Animation|Children|Comedy
# 17                                      Drama
# 18                      Drama|Mystery|Romance
# 19                           Comedy|Drama|War

# %% [markdown]
# ## KNN With Means

# %%
sim_options = {'name': 'cosine',
               'min_support': 5,
               'user_based': True}

knn_with_means = KNNWithMeans(k=24,sim_options=sim_options)

# %%
knn_with_means_model = cf_model(knn_with_means, trainset, testset, data, 20)
knn_with_means_model.fit_and_predict()
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.5882
# 0.588

# %%
knn_with_means_model.cross_validate()
# Out:
# Cross Validating the data...
# Mean CV RMSE is 0.865
# 0.865

# %%
dump.dump('model/trained_models/KNNWithMeans_Model',algo=knn_with_means_model,predictions=knn_with_means_model.pred_test)

# %%
knn_with_means_model.recommend_all(sveta_user_id).merge(movie_df, on='movieId', how='left').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   47347    1260     5.000000
# 1   47347    3030     5.000000
# 2   47347    1219     4.989073
# 3   47347     750     4.976906
# 4   47347    1148     4.965692
# 5   47347    1218     4.951567
# 6   47347    7156     4.925159
# 7   47347     162     4.911114
# 8   47347    1734     4.911033
# 9   47347    3089     4.903689
# 10  47347    3307     4.900793
# 11  47347    4642     4.890407
# 12  47347     306     4.882571
# 13  47347    2732     4.875459
# 14  47347     745     4.847205
# 15  47347    1280     4.843413
# 16  47347    2731     4.836882
# 17  47347     260     4.833490
# 18  47347     950     4.817007
# 19  47347   64622     4.816119
#
#                                                 title  \
# 0                                            M (1931)
# 1                                      Yojimbo (1961)
# 2                                       Psycho (1960)
# 3   Dr. Strangelove or: How I Learned to Stop Worr...
# 4         Wallace & Gromit: The Wrong Trousers (1993)
# 5           Killer, The (Die xue shuang xiong) (1989)
# 6   Fog of War: Eleven Lessons from the Life of Ro...
# 7                                        Crumb (1994)
# 8             My Life in Pink (Ma vie en rose) (1997)
# 9   Bicycle Thieves (a.k.a. The Bicycle Thief) (a....
# 10                                 City Lights (1931)
# 11                   Hedwig and the Angry Inch (2000)
# 12   Three Colors: Red (Trois couleurs: Rouge) (1994)
# 13                Jules and Jim (Jules et Jim) (1961)
# 14             Wallace & Gromit: A Close Shave (1995)
# 15  Raise the Red Lantern (Da hong deng long gao g...
# 16     400 Blows, The (Les quatre cents coups) (1959)
# 17          Star Wars: Episode IV - A New Hope (1977)
# 18                               Thin Man, The (1934)
# 19                                 Reader, The (2008)
#
#                              genres
# 0          Crime|Film-Noir|Thriller
# 1                  Action|Adventure
# 2                      Crime|Horror
# 3                        Comedy|War
# 4   Animation|Children|Comedy|Crime
# 5       Action|Crime|Drama|Thriller
# 6                   Documentary|War
# 7                       Documentary
# 8                      Comedy|Drama
# 9                             Drama
# 10             Comedy|Drama|Romance
# 11             Comedy|Drama|Musical
# 12                            Drama
# 13                    Drama|Romance
# 14        Animation|Children|Comedy
# 15                            Drama
# 16                      Crime|Drama
# 17          Action|Adventure|Sci-Fi
# 18                     Comedy|Crime
# 19                    Drama|Romance

# %%
knn_with_means_model.recommend_all(hamid_user_id).merge(movie_df, on='movieId', how='left').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   23579    1260     4.555931
# 1   23579    3030     4.518360
# 2   23579    1218     4.448711
# 3   23579    7156     4.421844
# 4   23579    1734     4.404420
# 5   23579    1212     4.394791
# 6   23579    4642     4.384253
# 7   23579    3089     4.378405
# 8   23579     903     4.369080
# 9   23579     162     4.367651
# 10  23579    1254     4.362859
# 11  23579   44555     4.356324
# 12  23579     912     4.349380
# 13  23579     904     4.341470
# 14  23579    2732     4.341348
# 15  23579    1280     4.339053
# 16  23579   64622     4.314351
# 17  23579     950     4.310552
# 18  23579    1617     4.309791
# 19  23579    2731     4.308418
#
#                                                 title  \
# 0                                            M (1931)
# 1                                      Yojimbo (1961)
# 2           Killer, The (Die xue shuang xiong) (1989)
# 3   Fog of War: Eleven Lessons from the Life of Ro...
# 4             My Life in Pink (Ma vie en rose) (1997)
# 5                               Third Man, The (1949)
# 6                    Hedwig and the Angry Inch (2000)
# 7   Bicycle Thieves (a.k.a. The Bicycle Thief) (a....
# 8                                      Vertigo (1958)
# 9                                        Crumb (1994)
# 10           Treasure of the Sierra Madre, The (1948)
# 11  Lives of Others, The (Das leben der Anderen) (...
# 12                                  Casablanca (1942)
# 13                                 Rear Window (1954)
# 14                Jules and Jim (Jules et Jim) (1961)
# 15  Raise the Red Lantern (Da hong deng long gao g...
# 16                                 Reader, The (2008)
# 17                               Thin Man, The (1934)
# 18                           L.A. Confidential (1997)
# 19     400 Blows, The (Les quatre cents coups) (1959)
#
#                               genres
# 0           Crime|Film-Noir|Thriller
# 1                   Action|Adventure
# 2        Action|Crime|Drama|Thriller
# 3                    Documentary|War
# 4                       Comedy|Drama
# 5         Film-Noir|Mystery|Thriller
# 6               Comedy|Drama|Musical
# 7                              Drama
# 8     Drama|Mystery|Romance|Thriller
# 9                        Documentary
# 10    Action|Adventure|Drama|Western
# 11            Drama|Romance|Thriller
# 12                     Drama|Romance
# 13                  Mystery|Thriller
# 14                     Drama|Romance
# 15                             Drama
# 16                     Drama|Romance
# 17                      Comedy|Crime
# 18  Crime|Film-Noir|Mystery|Thriller
# 19                       Crime|Drama

# %% [markdown]
# ## SVD default

# %%
# Retrain the model
svd = SVD()
svd_model = cf_model(svd, trainset, testset, data, 20)
svd_model.fit_and_predict()
# Out:
# RMSE: 0.5400
# 0.54

# %%
svd_model.cross_validate()
# Out:
# Cross Validating the data...
# Mean CV RMSE is 0.856
# 0.856

# %%
dump.dump('model/trained_models/SVDDefault_Model',algo=svd_model,predictions=svd_model.pred_test)

# %%
svd_model.recommend_all(sveta_user_id).merge(movie_df, on='movieId', how='inner').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   47347     904     4.622796
# 1   47347    1251     4.587854
# 2   47347    1212     4.526722
# 3   47347    3307     4.525341
# 4   47347    3435     4.506472
# 5   47347    1280     4.501883
# 6   47347     515     4.498875
# 7   47347     922     4.489372
# 8   47347    1293     4.488867
# 9   47347   48394     4.481020
# 10  47347    2300     4.476486
# 11  47347    2010     4.473127
# 12  47347     800     4.469529
# 13  47347    1263     4.468078
# 14  47347    1234     4.448268
# 15  47347     720     4.447127
# 16  47347    3089     4.445977
# 17  47347    1223     4.445796
# 18  47347    6867     4.444381
# 19  47347     908     4.439496
#
#                                                 title  \
# 0                                  Rear Window (1954)
# 1                                   8 1/2 (8½) (1963)
# 2                               Third Man, The (1949)
# 3                                  City Lights (1931)
# 4                             Double Indemnity (1944)
# 5   Raise the Red Lantern (Da hong deng long gao g...
# 6                      Remains of the Day, The (1993)
# 7       Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 8                                       Gandhi (1982)
# 9    Pan's Labyrinth (Laberinto del fauno, El) (2006)
# 10                              Producers, The (1968)
# 11                                  Metropolis (1927)
# 12                                   Lone Star (1996)
# 13                            Deer Hunter, The (1978)
# 14                                  Sting, The (1973)
# 15  Wallace & Gromit: The Best of Aardman Animatio...
# 16  Bicycle Thieves (a.k.a. The Bicycle Thief) (a....
# 17    Grand Day Out with Wallace and Gromit, A (1989)
# 18                          Station Agent, The (2003)
# 19                          North by Northwest (1959)
#
#                                         genres
# 0                             Mystery|Thriller
# 1                                Drama|Fantasy
# 2                   Film-Noir|Mystery|Thriller
# 3                         Comedy|Drama|Romance
# 4                        Crime|Drama|Film-Noir
# 5                                        Drama
# 6                                Drama|Romance
# 7                      Drama|Film-Noir|Romance
# 8                                        Drama
# 9                       Drama|Fantasy|Thriller
# 10                                      Comedy
# 11                                Drama|Sci-Fi
# 12                       Drama|Mystery|Western
# 13                                   Drama|War
# 14                                Comedy|Crime
# 15                  Adventure|Animation|Comedy
# 16                                       Drama
# 17  Adventure|Animation|Children|Comedy|Sci-Fi
# 18                                Comedy|Drama
# 19   Action|Adventure|Mystery|Romance|Thriller

# %%
svd_model.recommend_all(hamid_user_id).merge(movie_df, on='movieId', how='inner').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   23579    1252     4.497889
# 1   23579    1207     4.355734
# 2   23579     904     4.342237
# 3   23579     162     4.338948
# 4   23579     922     4.332010
# 5   23579    1260     4.311628
# 6   23579      29     4.279683
# 7   23579    3198     4.272830
# 8   23579    3503     4.268450
# 9   23579    2467     4.262612
# 10  23579    2863     4.256899
# 11  23579     908     4.256614
# 12  23579     800     4.247482
# 13  23579    2300     4.240507
# 14  23579     910     4.236631
# 15  23579     903     4.211989
# 16  23579    2966     4.210735
# 17  23579    7156     4.210537
# 18  23579    1952     4.209531
# 19  23579     912     4.198986
#
#                                                 title  \
# 0                                    Chinatown (1974)
# 1                        To Kill a Mockingbird (1962)
# 2                                  Rear Window (1954)
# 3                                        Crumb (1994)
# 4       Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 5                                            M (1931)
# 6   City of Lost Children, The (Cité des enfants p...
# 7                                     Papillon (1973)
# 8                           Solaris (Solyaris) (1972)
# 9   Name of the Rose, The (Name der Rose, Der) (1986)
# 10                         Hard Day's Night, A (1964)
# 11                          North by Northwest (1959)
# 12                                   Lone Star (1996)
# 13                              Producers, The (1968)
# 14                            Some Like It Hot (1959)
# 15                                     Vertigo (1958)
# 16                         Straight Story, The (1999)
# 17  Fog of War: Eleven Lessons from the Life of Ro...
# 18                             Midnight Cowboy (1969)
# 19                                  Casablanca (1942)
#
#                                        genres
# 0            Crime|Film-Noir|Mystery|Thriller
# 1                                       Drama
# 2                            Mystery|Thriller
# 3                                 Documentary
# 4                     Drama|Film-Noir|Romance
# 5                    Crime|Film-Noir|Thriller
# 6      Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 7                                 Crime|Drama
# 8                        Drama|Mystery|Sci-Fi
# 9                Crime|Drama|Mystery|Thriller
# 10                   Adventure|Comedy|Musical
# 11  Action|Adventure|Mystery|Romance|Thriller
# 12                      Drama|Mystery|Western
# 13                                     Comedy
# 14                               Comedy|Crime
# 15             Drama|Mystery|Romance|Thriller
# 16                            Adventure|Drama
# 17                            Documentary|War
# 18                                      Drama
# 19                              Drama|Romance

# %% [markdown]
# ## SVD tuned

# %%
param_grid = {
    'n_factors': [10, 50, 90],
    'n_epochs': [5, 20, 50], 
    'lr_all': [0.001, 0.005, 0.02],
    'reg_all': [0.005, 0.02, 0.1]}

gs = GridSearchCV(SVD, param_grid, measures=['mae'], cv=3, n_jobs = -1)
gs.fit(data)
params = gs.best_params['mae']
svdtuned = SVD(n_factors=params['n_factors'], n_epochs=params['n_epochs'],lr_all=params['lr_all'], reg_all=params['reg_all'])
svdtuned.fit(trainset)
svdtuned_predictions = svdtuned.test(testset)

# %%
dump.dump('model/trained_models/SVDTuned_Model',algo=svdtuned,predictions=svdtuned_predictions)

# %%
params
# Out:
# {'n_factors': 90, 'n_epochs': 50, 'lr_all': 0.02, 'reg_all': 0.1}

# %%
svd_tuned_model = cf_model(svdtuned, trainset, testset, data, 20)
svd_tuned_model.fit_and_predict()
# Out:
# RMSE: 0.5637
# 0.564

# %%
svd_tuned_model.cross_validate()
# Out:
# Cross Validating the data...
# Mean CV RMSE is 0.83
# 0.83

# %%
svd_tuned_model.recommend_all(sveta_user_id).merge(movie_df, on='movieId', how='inner').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   47347    5971     4.739030
# 1   47347     904     4.704428
# 2   47347    7156     4.662621
# 3   47347     745     4.660284
# 4   47347    1223     4.660019
# 5   47347    1147     4.650222
# 6   47347    5690     4.641063
# 7   47347     720     4.625189
# 8   47347      41     4.622624
# 9   47347    1263     4.587113
# 10  47347    3742     4.578012
# 11  47347    1234     4.566865
# 12  47347   54503     4.566332
# 13  47347   66097     4.559908
# 14  47347    3468     4.542749
# 15  47347    4642     4.541848
# 16  47347    3030     4.534519
# 17  47347     123     4.523179
# 18  47347    1203     4.504152
# 19  47347    1260     4.496562
#
#                                                 title  \
# 0        My Neighbor Totoro (Tonari no Totoro) (1988)
# 1                                  Rear Window (1954)
# 2   Fog of War: Eleven Lessons from the Life of Ro...
# 3              Wallace & Gromit: A Close Shave (1995)
# 4     Grand Day Out with Wallace and Gromit, A (1989)
# 5                           When We Were Kings (1996)
# 6      Grave of the Fireflies (Hotaru no haka) (1988)
# 7   Wallace & Gromit: The Best of Aardman Animatio...
# 8                                  Richard III (1995)
# 9                             Deer Hunter, The (1978)
# 10                         Battleship Potemkin (1925)
# 11                                  Sting, The (1973)
# 12                                    Superbad (2007)
# 13                                    Coraline (2009)
# 14                                Hustler, The (1961)
# 15                   Hedwig and the Angry Inch (2000)
# 16                                     Yojimbo (1961)
# 17      Chungking Express (Chung Hing sam lam) (1994)
# 18                                12 Angry Men (1957)
# 19                                           M (1931)
#
#                                         genres
# 0             Animation|Children|Drama|Fantasy
# 1                             Mystery|Thriller
# 2                              Documentary|War
# 3                    Animation|Children|Comedy
# 4   Adventure|Animation|Children|Comedy|Sci-Fi
# 5                                  Documentary
# 6                          Animation|Drama|War
# 7                   Adventure|Animation|Comedy
# 8                                    Drama|War
# 9                                    Drama|War
# 10                                   Drama|War
# 11                                Comedy|Crime
# 12                                      Comedy
# 13                  Animation|Fantasy|Thriller
# 14                                       Drama
# 15                        Comedy|Drama|Musical
# 16                            Action|Adventure
# 17                       Drama|Mystery|Romance
# 18                                       Drama
# 19                    Crime|Film-Noir|Thriller

# %%
svd_tuned_model.recommend_all(anti_sveta_user_id).merge(movie_df, on='movieId', how='inner').head(20)
# Out:
#    userId movieId  pred_rating  \
# 0   14433     926     5.000000
# 1   14433     950     5.000000
# 2   14433   87232     5.000000
# 3   14433   89745     5.000000
# 4   14433     955     4.995493
# 5   14433   31410     4.982717
# 6   14433   97938     4.967289
# 7   14433   70286     4.960785
# 8   14433   63082     4.950633
# 9   14433   59315     4.950124
# 10  14433    2357     4.945085
# 11  14433   76093     4.925163
# 12  14433   81845     4.910593
# 13  14433     260     4.904324
# 14  14433   79091     4.894284
# 15  14433    3030     4.891562
# 16  14433    5903     4.891361
# 17  14433    3741     4.888414
# 18  14433    1280     4.886346
# 19  14433     922     4.886002
#
#                                                 title  \
# 0                                All About Eve (1950)
# 1                                Thin Man, The (1934)
# 2                           X-Men: First Class (2011)
# 3                                Avengers, The (2012)
# 4                             Bringing Up Baby (1938)
# 5                    Downfall (Untergang, Der) (2004)
# 6                                   Life of Pi (2012)
# 7                                   District 9 (2009)
# 8                          Slumdog Millionaire (2008)
# 9                                     Iron Man (2008)
# 10         Central Station (Central do Brasil) (1998)
# 11                    How to Train Your Dragon (2010)
# 12                          King's Speech, The (2010)
# 13          Star Wars: Episode IV - A New Hope (1977)
# 14                               Despicable Me (2010)
# 15                                     Yojimbo (1961)
# 16                                 Equilibrium (2002)
# 17                                    Badlands (1973)
# 18  Raise the Red Lantern (Da hong deng long gao g...
# 19      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
#
#                                        genres
# 0                                       Drama
# 1                                Comedy|Crime
# 2        Action|Adventure|Sci-Fi|Thriller|War
# 3                Action|Adventure|Sci-Fi|IMAX
# 4                              Comedy|Romance
# 5                                   Drama|War
# 6                        Adventure|Drama|IMAX
# 7                     Mystery|Sci-Fi|Thriller
# 8                         Crime|Drama|Romance
# 9                     Action|Adventure|Sci-Fi
# 10                                      Drama
# 11  Adventure|Animation|Children|Fantasy|IMAX
# 12                                      Drama
# 13                    Action|Adventure|Sci-Fi
# 14            Animation|Children|Comedy|Crime
# 15                           Action|Adventure
# 16                     Action|Sci-Fi|Thriller
# 17                       Crime|Drama|Thriller
# 18                                      Drama
# 19                    Drama|Film-Noir|Romance

# %% [markdown]
# ## Calculation of the quality of the collaborative filtering

# %% [markdown]
#  **Variety**

# %%
eval_knn_basic = Evaluate(knn_basic_model)
eval_knn_basic.Variety()
# Out:
# (0.07229000000000001, 0.0047038175985044325)

# %%
eval_knn_wmeans = Evaluate(knn_with_means_model)
eval_knn_wmeans.Variety()
# Out:
# (0.062430000000000006, 0.005812495161288308)

# %%
eval_svd = Evaluate(svd_model)
eval_svd.Variety()
# Out:
# (0.17796, 0.007712224063135095)

# %%
eval_tuned_svd = Evaluate(svd_tuned_model)
eval_tuned_svd.Variety()
# Out:
# (0.19802, 0.010099485135391805)

# %% [markdown]
# ## Analysis of similarity matrices

# %%
simMat_knn_basic = knn_basic_model.compute_similarities()
simMat_knn_with_means = knn_with_means_model.compute_similarities()
simMat_knn_pearson = knn_pearson_model.compute_similarities()

# %%
def sim_matrices_info(dict_of_matrices):
    df = pd.DataFrame(columns=['mean'], index=dict_of_matrices.keys())
    df['mean'] =  [x.mean() for x in dict_of_matrices.values()]
    return df

# %%
sim_matrices_info({'knn_basic': simMat_knn_basic, 'knn_with_means': simMat_knn_with_means, 'knn_pearson' :simMat_knn_pearson})
# Out:
#                     mean
# knn_basic       0.397944
# knn_with_means  0.853196
# knn_pearson     0.140685

# %%
import seaborn as sns
sns.heatmap(simMat_knn_pearson)
# Out:
# <Axes: >

# %% [markdown]
# **Personalization**

# %%
def compute_prediction_overlap(userId_1, userId_2, model):
    overlap_array = []
    rec_1 = set(model.recommend_all(userId_1).movieId.values[:50])
    rec_2 = set(model.recommend_all(userId_2).movieId.values[:50])
    overlap = rec_1 
    return len(rec_1.intersection(rec_2))

def return_similarities(userId, model, simMat):
    df = pd.DataFrame(columns=["uuid", "similarity", "overlap"])
    uuid = model.trainset.to_inner_uid(userId)
    sim_array = simMat[uuid]
    uuid_array = np.arange(simMat.shape[0])
    df["uuid"] = uuid_array
    df["similarity"] = sim_array
    df["overlap"] = df.apply(lambda x: compute_prediction_overlap(userId, model.trainset.to_raw_uid(x["uuid"]), model), axis=1)
    return df.sort_values(by=["similarity"]).reset_index(drop=True)

# %%
hamid_user_id, sveta_user_id, anti_hamid_user_id, anti_sveta_user_id
# Out:
# (23579, 47347, 96258, 14433)

# %%
random_user = np.random.choice(ratings.userId.unique())

# %%
result_knn_with_means = return_similarities(random_user, knn_with_means_model, simMat_knn_with_means)
result_knn_basic = return_similarities(random_user, knn_basic_model, simMat_knn_basic )
result_knn_pearson = return_similarities(random_user, knn_pearson_model, simMat_knn_pearson )

# %%
#result_svd_means = return_similarities(random_user, svd_model, simMat_knn_with_means )
result_svd_basic = return_similarities(random_user, svd_model, simMat_knn_basic )
#result_svd_tuned_means = return_similarities(random_user, svd_tuned_model, simMat_knn_with_means )
result_svd_tuned_basic = return_similarities(random_user, svd_tuned_model, simMat_knn_basic )
#result_svd_tuned_pearson = return_similarities(random_user, svd_tuned_model, simMat_knn_pearson )

# %%
result_anti_hamid_df = return_similarities(anti_hamid_user_id, svd_model, simMat_knn_with_means)
result_hamid_df = return_similarities(hamid_user_id, svd_model, simMat_knn_with_means)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#plt.grid(True)
plt.xlim=(0.8,1)
#plt.plot(result_svd_means.similarity, result_svd_means .overlap, "b*", linewidth=0.2, label="result_svd_means ")
plt.plot(result_svd_basic.similarity, result_svd_basic.overlap, "m*", linewidth=0.2, label="result_svd_basic")
plt.plot(result_svd_tuned_basic.similarity, result_svd_tuned_basic.overlap, "y*", linewidth=0.2, label="result_svd_tuned_basic")
#plt.plot(result_svd_tuned_means.similarity, result_svd_tuned_means.overlap, "c*", linewidth=0.2, label="result_svd_tuned_with_means")
#plt.plot(result_svd_tuned_pearson.similarity, result_svd_tuned_pearson.overlap, "k.", linewidth=0.2, label="result_svd_tuned_pearson")
#plt.plot(result_knn_with_means.similarity, result_knn_with_means.overlap, "g*", linewidth=0.2, label="result_knn_with_means")
#plt.plot(result_knn_basic.similarity, result_knplt.plot(result_svd_basic.similarity, result_svd_basic.overlap, "m*", linewidth=0.2, label="result_svd_basic")n_basic.overlap, "k*", linewidth=0.2, label="result_knn_basic")
#plt.plot(result_knn_pearson.similarity, result_knn_pearson.overlap, "r*", linewidth=0.2, label="result_knn_pearson")
plt.xlabel('Similarity')
plt.ylabel('Overlap')

plt.legend();

# %% [markdown]
# ## Upload trained models and their predictions

# %%
knn_basic_preds, knn_basic_algo = dump.load('./model/trained_models/KNNBasic_Model')
knn_basic_model = cf_model(knn_basic_algo, trainset, testset, data, 10, knn_basic_preds)
knn_basic_model.fit_and_predict()

# %%
knn_wmeans_preds, knn_wmeans_algo = dump.load('./model/trained_models/KNNWithMeans_Model')
knn_with_means_model = cf_model(knn_wmeans_algo, trainset, testset, data, 10, knn_wmeans_preds)
knn_with_means_model.fit_and_predict()

# %%
svd_preds, svd_algo = dump.load('./model/trained_models/SVDDefault_Model')
svd_model = cf_model(svd_algo, trainset, testset, data, 10, svd_preds)
svd_model.fit_and_predict()
